# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("../data/ethiopia.csv")

df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  11.73    22.75     3.44      19.31          0.0  41.79  2.73
# 1  2015    2  12.30    24.01     4.09      19.92          0.0  33.29  2.39
# 2  2015    3  12.49    24.17     3.97      20.20          0.0  33.83  1.77
# 3  2015    4  14.08    23.78     6.90      16.88          0.0  38.84  0.87
# 4  2015    5  14.06    23.15     7.32      15.83          0.0  47.07  1.34
#
#    WS2M_MAX     PS  QV2M
# 0      5.07  77.13  4.00
# 1      4.19  77.14  3.35
# 2      2.76  77.11  3.43
# 3      1.28  77.07  4.60
# 4      2.14  77.01  5.58

# %%
# Replace -999
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  11.73    22.75     3.44      19.31         0.00  41.79  2.73
# 1     2015    2  12.30    24.01     4.09      19.92         0.00  33.29  2.39
# 2     2015    3  12.49    24.17     3.97      20.20         0.00  33.83  1.77
# 3     2015    4  14.08    23.78     6.90      16.88         0.00  38.84  0.87
# 4     2015    5  14.06    23.15     7.32      15.83         0.00  47.07  1.34
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  16.99    24.29    11.80      12.49         5.27  73.87  1.79
# 4104  2026   87  15.29    19.58    12.08       7.50         6.46  80.85  1.13
# 4105  2026   88  16.28    22.34    11.69      10.65         9.53  77.96  1.30
# 4106  2026   89  17.66    25.31    11.08      14.23         0.85  68.88  2.02
# 4107  2026   90  18.25    26.36    12.14      14.22         0.40  63.95  2.18
#
#       WS2M_MAX     PS   QV2M
# ...

# %%
# Create DATE column
df["DATE"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# %%
# Add Month
df["Month"] = df["DATE"].dt.month

# %%
# Add Country column
df["Country"] = "Ethiopia"

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate rows found

# %%
df.describe()
# Out:
#               YEAR          DOY         T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.00000  4108.000000  4108.000000
# mean   2020.131451   180.121227    16.06850    23.199175    10.227544
# min    2015.000000     1.000000    10.03000    15.650000     1.170000
# 25%    2017.000000    86.000000    14.82000    21.110000     8.417500
# 50%    2020.000000   179.000000    16.04000    22.740000    10.990000
# 75%    2023.000000   272.000000    17.36000    25.170000    12.220000
# max    2026.000000   366.000000    21.53000    30.930000    15.680000
# std       3.248907   106.294767     1.89805     2.751471     2.607256
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     12.971631     3.633795    68.408588     1.979998     3.575246
# min       3.560000     0.000000    14.420000     0.460000     0.790000
# ...

# %% [markdown]
# - Average temperature (T2M) is around 16.07°C, indicating a moderate climate overall.
# - Maximum temperatures (T2M_MAX) reach about 30.93°C, while the average daily high is around 23.2°C.
# - Precipitation (PRECTOTCORR) is highly variable, ranging from 0 mm to ~82.3 mm, which highlights significant rainfall spikes.
# - Humidity (RH2M) ranges widely (from 14.4% to 91.9%) → this suggests distinct seasonal changes between dry and wet periods.
# - Wind Speed (WS2M) is generally low to moderate, averaging around 1.98 m/s.

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# DATE           0
# Month          0
# Country        0
# dtype: int64

# %% [markdown]
# - Dataset has negligible missing values (<1%)
# - Forward fill was applied for consistency

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# T2M_RANGE      0.0
# PRECTOTCORR    0.0
# RH2M           0.0
# WS2M           0.0
# WS2M_MAX       0.0
# PS             0.0
# QV2M           0.0
# DATE           0.0
# Month          0.0
# Country        0.0
# dtype: float64

# %%
from scipy import stats

z_scores = np.abs(stats.zscore(df[[
    "T2M", "T2M_MAX", "T2M_MIN", 
    "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"
]].dropna()))

outliers = (z_scores > 3).sum()
outliers
# Out:
# np.int64(137)

# %% [markdown]
# - 137 outliers detected using Z-score > 3
# - Outliers retained because they may represent extreme climate events

# %%
df = df.ffill()

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

monthly_temp.plot(kind="line", figsize=(10,5))
plt.title("Average Monthly Temperature (Ethiopia)")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# - Highest temprature occur around March-May
# - Lowest temprature occur around  Novmberr

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

monthly_rain.plot(kind="bar", figsize=(10,5))
plt.title("Monthly Precipitation (Ethiopia)")
plt.xlabel("Month")
plt.ylabel("Rainfall (mm)")
plt.show()

# %% [markdown]
# - Rainfall peaks in July–Augest
# - Less rainfall on Decemeber-January

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# T2M vs T2M_MAX → strong positive
# T2M vs RH2M → negative (hot = dry)

# %%
sns.scatterplot(x="T2M", y="RH2M", data=df)
plt.show()

sns.scatterplot(x="T2M_RANGE", y="WS2M", data=df)
plt.show()

# %% [markdown]
# - T2M vs. RH2M: As average temperature increases, humidity generally decreases, indicating a typical inverse relationship between heat and moisture.
# - T2M_RANGE vs. WS2M: A clear positive correlation shows that wind speeds tend to increase on days with a larger gap between maximum and minimum temperatures.

# %%
plt.hist(df["PRECTOTCORR"], bins=50)
plt.title("Rainfall Distribution")
plt.show()

# %% [markdown]
# - few high values and many low vlaues

# %%
df.to_csv("../data/ethiopia_clean.csv", index=False)
